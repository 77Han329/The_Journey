# %%
import torch.nn as nn
import torch.nn.functional as F
import torch

# %%
class My_Embedding(nn.Module):
    def __init__(self, vocabsize: str, embd_size: str, device=None, dtype=None):
        super.__init()
        
        factory_kwars = {'device': device,
                         'dtype': dtype}
        
        self.weight == nn.Parameter(torch.empty(vocabsize,embd_size),**factory_kwargs)
        
        nn.init.t
